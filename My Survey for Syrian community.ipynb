# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import math as mt

data = pd.read_csv("D:/Perfect Social Media.csv")
data.head()
# Out:
#                    country        id          type  gender  age     city  \
# 0  Syrian Arabic Rebuplic   10570881  Social Media    Male   28  Latakia
# 1  Syrian Arabic Rebuplic    1582209  Social Media  Female   24     Homs
# 2  Syrian Arabic Rebuplic   23172353  Social Media    Male   29   Tartus
# 3  Syrian Arabic Rebuplic   19256068  Social Media    Male   32  Latakia
# 4  Syrian Arabic Rebuplic   16010632  Social Media    Male   34  Latakia
#
#                 pform    pform_2  use_begin  min_hours  max_hours  min_person  \
# 0             Twitter  Instagram       2014          2          4           1
# 1            Facebook   WhatsApp       2009          1          5           3
# 2  Facebook-Messenger    Twitter       2011          2          4           1
# 3            Facebook  Instagram       2006          1          3           0
# 4            Facebook   WhatsApp       2012          2          5           2
#
#    max_person     using_kind   opinion  rate
# ...

# %%
data = data.drop("country",axis=1)

# %%
data = data.drop("id",axis=1)

# %%
data.head()
# Out:
#            type  gender  age     city               pform    pform_2  \
# 0  Social Media    Male   28  Latakia             Twitter  Instagram
# 1  Social Media  Female   24     Homs            Facebook   WhatsApp
# 2  Social Media    Male   29   Tartus  Facebook-Messenger    Twitter
# 3  Social Media    Male   32  Latakia            Facebook  Instagram
# 4  Social Media    Male   34  Latakia            Facebook   WhatsApp
#
#    use_begin  min_hours  max_hours  min_person  max_person     using_kind  \
# 0       2014          2          4           1           2           NEWS
# 1       2009          1          5           3          10       Studying
# 2       2011          2          4           1           5  Communication
# 3       2006          1          3           0           3           NEWS
# 4       2012          2          5           2           6  Communication
#
#     opinion  rate
# 0  Positive     5
# 1   Nothing     4
# 2  Positive     4
# 3   Nothing     2
# ...

# %%
((data.use_begin.value_counts()*100 / sum(data.use_begin.value_counts()))).plot(kind="bar")
plt.grid(True)
plt.show()

# %%
data.city.value_counts().plot(kind="pie",autopct="%1.1f%%",figsize=(10,10),fontsize=12,title="Distribution of samples to Syrian Cities")
# Out:
# <AxesSubplot:title={'center':'Distribution of samples to Syrian Cities'}, ylabel='city'>

# %%
data.pform.value_counts().plot(kind="pie",autopct="%1.1f%%",figsize=(10,10),fontsize=12,title="Distribution of Platforms to Samples")
# Out:
# <AxesSubplot:title={'center':'Distribution of Platforms to Samples'}, ylabel='pform'>

# %%
data.using_kind.value_counts().plot(kind="pie",autopct="%1.1f%%",figsize=(10,10),fontsize=12,title="Distribution Kind of using to Samples")
# Out:
# <AxesSubplot:title={'center':'Distribution Kind of using to Samples'}, ylabel='using_kind'>

# %%
facebook_using = data[(data.city =="Latakia")&(data.pform=="Facebook")]

# %%
(facebook_using.gender.value_counts()*100 / sum(facebook_using.gender.value_counts())).map('%{:,.1f}'.format)
# Out:
# Male      %72.7
# Female    %27.3
# Name: gender, dtype: object

# %%
x=data.age
y=data.rate

plt.bar(x,y,color="green")
plt.xlabel="Rate"
plt.ylabel= "Age"
plt.grid(True)
plt.show()

# %%
data_example = pd.DataFrame({"Age":data.age,"Max_Hours":data.max_hours})
data_example.plot.bar("Age","Max_Hours",color="red",figsize=(10,4))
plt.xlabel=("Max_Hours")
plt.ylabel=( "Age")
plt.grid(True)
#plt.plot(figsize=(8,8))
plt.show()
