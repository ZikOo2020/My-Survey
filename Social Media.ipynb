# %%
import pandas as pd 
import math as mt
import random as rn 

data = pd.read_csv("C:/Users/Zualfiqar/Desktop/New Social Media.csv")
data.head()
# Out:
#         id          type  gender  age  city            platform platform_2  \
# 0  8630528  Social Media    Male   28  LAT              Twitter        NaN
# 1  3164928  Social Media  Female   24   HOM            Facebook   WhatsApp
# 2  9064194  Social Media    Male   29   TAR  Facebook-Messenger    Twitter
# 3  9557891  Social Media    Male   32   LAT            Facebook  Instagram
# 4  8011396  Social Media    Male   34   LAT            Facebook   WhatsApp
#
#    use_begin  min_hours  max_hours  min_person  max_person     using_kind  \
# 0       2014        2.0        4.0         1.0         2.0           NEWS
# 1       2009        1.0        5.0         3.0        10.0            NaN
# 2       2011        2.0        4.0         1.0         5.0  Communication
# 3       2006        1.0        3.0         0.0         3.0           NEWS
# 4       2012        2.0        5.0         2.0         6.0  Communication
#
#     opinion  rate  rate_2
# 0  Positive     5     NaN
# ...

# %%
data1 = data.drop("id",axis=1)
data2 = data1.drop("rate_2",axis=1)
data3 = data2.drop("type",axis=1)

# %%
data3.describe()
# Out:
#              age    use_begin  min_hours  max_hours  min_person  max_person  \
# count  60.000000    60.000000  55.000000  59.000000   59.000000   59.000000
# mean   28.250000  2011.200000   2.581818   6.067797    2.016949    6.677966
# std     4.939035     2.556481   2.114245   2.917630    1.479650    5.140913
# min    21.000000  2006.000000   1.000000   1.000000    0.000000    1.000000
# 25%    25.000000  2010.000000   1.000000   4.000000    1.000000    3.000000
# 50%    28.000000  2011.000000   2.000000   6.000000    2.000000    5.000000
# 75%    29.250000  2013.000000   3.000000   8.000000    3.000000    8.000000
# max    44.000000  2018.000000  12.000000  14.000000    6.000000   30.000000
#
#             rate
# count  60.000000
# mean    3.516667
# std     0.892372
# min     1.000000
# 25%     3.000000
# 50%     4.000000
# 75%     4.000000
# max     5.000000

# %%
data3[data3.isna().any(axis=1)]
# Out:
#     gender  age  city   platform platform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT     Twitter        NaN       2014        2.0        4.0
# 1   Female   24   HOM   Facebook   WhatsApp       2009        1.0        5.0
# 5     Male   28   HOM   Facebook  Instagram       2010        NaN        2.0
# 13    Male   31   HOM   Facebook    Youtube       2010        2.0        8.0
# 17    Male   28   HOM   Facebook   Telegram       2009        NaN        2.0
# 19    Male   25   LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22   LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25   TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24   LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26   HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44   HOM   WhatsApp   Facebook       2014        3.0        5.0
# ...

# %%
min_hours = data3.min_hours.fillna(mt.floor(data3.min_hours.mean()))
data3.min_hours = min_hours
data3[data3.isna().any(axis=1)]
# Out:
#     gender  age  city   platform platform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT     Twitter        NaN       2014        2.0        4.0
# 1   Female   24   HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31   HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25   LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22   LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25   TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24   LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26   HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44   HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24   HAM   Facebook   Telegram       2016        2.0        NaN
# 43  Female   25   LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
max_hours = data3.max_hours.fillna(mt.ceil(data3.max_hours.mean()))
data3.max_hours = max_hours
data3[data3.isna().any(axis=1)]
# Out:
#     gender  age  city   platform platform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT     Twitter        NaN       2014        2.0        4.0
# 1   Female   24   HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31   HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25   LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22   LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25   TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24   LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26   HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44   HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24   HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25   LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
min_person = data3.min_person.fillna(mt.floor(data3.min_person.mean()))
data3.min_person = min_person
data3[data3.isna().any(axis=1)]
# Out:
#     gender  age  city   platform platform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT     Twitter        NaN       2014        2.0        4.0
# 1   Female   24   HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31   HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25   LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22   LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25   TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24   LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26   HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44   HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24   HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25   LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
max_person = data3.max_person.fillna(mt.ceil(data3.max_person.mean()))
data3.max_person = max_person
data3[data3.isna().any(axis=1)]
# Out:
#     gender  age  city   platform platform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT     Twitter        NaN       2014        2.0        4.0
# 1   Female   24   HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31   HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25   LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22   LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25   TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24   LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26   HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44   HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24   HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25   LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
data3.using_kind.value_counts()
# Out:
# Communication    25
# NEWS             12
# Work              8
# Studying          2
# Name: using_kind, dtype: int64

# %%
count =0
for i in data3.using_kind.isna():
    if(i == True):
        if count <=6:
            using_kind = data3.using_kind.fillna("Studying")
            data3.using_kind = using_kind
        else:
            using_kind = data3.using_kind.fillna("Work")
            data3.using_kind = using_kind
    count = count+1

# %%
data3[data3.isna().any(axis=1)]
# Out:
#   gender  age  city platform platform_2  use_begin  min_hours  max_hours  \
# 0   Male   28  LAT   Twitter        NaN       2014        2.0        4.0
#
#    min_person  max_person using_kind   opinion  rate
# 0         1.0         2.0       NEWS  Positive     5

# %%
data3.platform_2.value_counts()
# Out:
# WhatsApp              14
# Youtube               14
# Instagram              9
# Facebook               7
# Facebook-Messenger     6
# Telegram               6
# LinkedIn               1
# Twitter                1
# SnapChat               1
# Name: platform_2, dtype: int64

# %%
platform_2 = data3.platform_2.fillna("Instagram")
data3.platform_2 = platform_2
data3[data3.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [gender, age, city, platform, platform_2, use_begin, min_hours, max_hours, min_person, max_person, using_kind, opinion, rate]
# Index: []

# %%
data3
# Out:
#     gender  age  city            platform          platform_2  use_begin  \
# 0     Male   28  LAT              Twitter           Instagram       2014
# 1   Female   24   HOM            Facebook            WhatsApp       2009
# 2     Male   29   TAR  Facebook-Messenger             Twitter       2011
# 3     Male   32   LAT            Facebook           Instagram       2006
# 4     Male   34   LAT            Facebook            WhatsApp       2012
# 5     Male   28   HOM            Facebook           Instagram       2010
# 6     Male   23   HOM            Facebook            SnapChat       2008
# 7     Male   30   HAM            Facebook  Facebook-Messenger       2011
# 8     Male   28   LAT            Facebook             Youtube       2009
# 9     Male   28   TAR            Facebook             Youtube       2006
# 10    Male   24   DAM            Telegram             Youtube       2015
# 11    Male   26   HOM            Facebook            Telegram       2011
# ...

# %%
data3[data3.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [gender, age, city, platform, platform_2, use_begin, min_hours, max_hours, min_person, max_person, using_kind, opinion, rate]
# Index: []

# %%
data3.describe()
# Out:
#              age    use_begin  min_hours  max_hours  min_person  max_person  \
# count  60.000000    60.000000  60.000000  60.000000   60.000000   60.000000
# mean   28.250000  2011.200000   2.533333   6.083333    2.016667    6.683333
# std     4.939035     2.556481   2.029166   2.895301    1.467058    5.097330
# min    21.000000  2006.000000   1.000000   1.000000    0.000000    1.000000
# 25%    25.000000  2010.000000   1.000000   4.000000    1.000000    3.000000
# 50%    28.000000  2011.000000   2.000000   6.000000    2.000000    5.000000
# 75%    29.250000  2013.000000   3.000000   8.000000    3.000000    8.000000
# max    44.000000  2018.000000  12.000000  14.000000    6.000000   30.000000
#
#             rate
# count  60.000000
# mean    3.516667
# std     0.892372
# min     1.000000
# 25%     3.000000
# 50%     4.000000
# 75%     4.000000
# max     5.000000

# %%
import matplotlib.pyplot as plt 

plt.hist(data3.using_kind)
plt.grid(True)
plt.show()

# %%
plt.bar(data3.gender,data3.max_person,color="c")
plt.xlabel("Age")
plt.ylabel("Max Person")
plt.grid(True)
plt.show()

# %%
plt.hist(data3.platform)
plt.grid(True)
plt.show()

# %%
plt.hist(data3.city)
plt.grid(True)
plt.show()

# %%
data3.city.value_counts()
# Out:
# LAT     26
# HOM     14
# TAR     11
# DAM      3
# HAM      3
# LAT      1
# IDL      1
# HAS      1
# Name: city, dtype: int64

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_csv("C:/Users/Zualfiqar/Desktop/Social Media.csv")
data.head()
# Out:
#            type  gender  age city               pform    pform_2  use_begin  \
# 0  Social Media    Male   28  LAT             Twitter        NaN       2014
# 1  Social Media  Female   24  HOM            Facebook   WhatsApp       2009
# 2  Social Media    Male   29  TAR  Facebook-Messenger    Twitter       2011
# 3  Social Media    Male   32  LAT            Facebook  Instagram       2006
# 4  Social Media    Male   34  LAT            Facebook   WhatsApp       2012
#
#    min_hours  max_hours  min_person  max_person     using_kind   opinion  \
# 0        2.0        4.0         1.0         2.0           NEWS  Positive
# 1        1.0        5.0         3.0        10.0            NaN   Nothing
# 2        2.0        4.0         1.0         5.0  Communication  Positive
# 3        1.0        3.0         0.0         3.0           NEWS   Nothing
# 4        2.0        5.0         2.0         6.0  Communication   Nothing
#
#    rate  rate_2
# 0     5     NaN
# 1     4     5.0
# 2     4     4.0
# ...

# %%
data1=data.drop("type",axis=1)
data1=data1.drop("rate_2",axis=1)

# %%
data1[data1.isna().any(axis=1)]
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 5     Male   28  HOM   Facebook  Instagram       2010        NaN        2.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 17    Male   28  HOM   Facebook   Telegram       2009        NaN        2.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# ...

# %%
data1.describe()
# Out:
#              age    use_begin  min_hours  max_hours  min_person  max_person  \
# count  60.000000    60.000000  55.000000  59.000000   59.000000   59.000000
# mean   28.250000  2011.200000   2.581818   6.067797    2.016949    6.677966
# std     4.939035     2.556481   2.114245   2.917630    1.479650    5.140913
# min    21.000000  2006.000000   1.000000   1.000000    0.000000    1.000000
# 25%    25.000000  2010.000000   1.000000   4.000000    1.000000    3.000000
# 50%    28.000000  2011.000000   2.000000   6.000000    2.000000    5.000000
# 75%    29.250000  2013.000000   3.000000   8.000000    3.000000    8.000000
# max    44.000000  2018.000000  12.000000  14.000000    6.000000   30.000000
#
#             rate
# count  60.000000
# mean    3.516667
# std     0.892372
# min     1.000000
# 25%     3.000000
# 50%     4.000000
# 75%     4.000000
# max     5.000000

# %%
import math as mt 
min_hours = data1.min_hours.fillna(mt.floor(data1.min_hours.mean()))
data1.min_hours = min_hours
data1[data1.isna().any(axis=1)]
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24  HAM   Facebook   Telegram       2016        2.0        NaN
# 43  Female   25  LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
max_hours = data1.max_hours.fillna(mt.ceil(data1.max_hours.mean()))
data1.max_hours = max_hours
data1[data1.isna().any(axis=1)]
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24  HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25  LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
min_person = data1.min_person.fillna(mt.floor(data1.min_person.mean()))
data1.min_person = min_person
data1[data1.isna().any(axis=1)]
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24  HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25  LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
max_person = data1.max_person.fillna(mt.ceil(data1.max_person.mean()))
data1.max_person = max_person
data1[data1.isna().any(axis=1)]
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24  HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25  LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
test = data1[data1.isna().any(axis=1)]
test
# Out:
#     gender  age city      pform    pform_2  use_begin  min_hours  max_hours  \
# 0     Male   28  LAT    Twitter        NaN       2014        2.0        4.0
# 1   Female   24  HOM   Facebook   WhatsApp       2009        1.0        5.0
# 13    Male   31  HOM   Facebook    Youtube       2010        2.0        8.0
# 19    Male   25  LAT    Youtube   Facebook       2009        4.0       10.0
# 25    Male   22  LAT   Facebook    Youtube       2014        5.0        6.0
# 28    Male   25  TAR   Facebook  Instagram       2012        1.0        3.0
# 35  Female   24  LAT   Facebook  Instagram       2014        2.0        6.0
# 36    Male   26  HOM   Facebook   WhatsApp       2009        1.0        4.0
# 40    Male   44  HOM   WhatsApp   Facebook       2014        3.0        5.0
# 42    Male   24  HAM   Facebook   Telegram       2016        2.0        7.0
# 43  Female   25  LAT   Facebook   WhatsApp       2014        6.0       14.0
# ...

# %%
count =0
for i in range(0,len(data1.using_kind.isna())):
    if data1.using_kind[i]!="NEWS" and data1.using_kind[i]!="Studying" and data1.using_kind[i]!="Communication" and data1.using_kind[i]!="Work":
        count = count+1
        if count <= 6:
            data1.using_kind[i]="Studying"
        else:
            data1.using_kind[i]="Work"
count
# Out:
# <ipython-input-56-10f0161b7134>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.using_kind[i]="Styding"
# <ipython-input-56-10f0161b7134>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.using_kind[i]="Work"
# 13

# %%
data1
# Out:
#     gender  age city               pform             pform_2  use_begin  \
# 0     Male   28  LAT             Twitter                 NaN       2014
# 1   Female   24  HOM            Facebook            WhatsApp       2009
# 2     Male   29  TAR  Facebook-Messenger             Twitter       2011
# 3     Male   32  LAT            Facebook           Instagram       2006
# 4     Male   34  LAT            Facebook            WhatsApp       2012
# 5     Male   28  HOM            Facebook           Instagram       2010
# 6     Male   23  HOM            Facebook            SnapChat       2008
# 7     Male   30  HAM            Facebook  Facebook-Messenger       2011
# 8     Male   28  LAT            Facebook             Youtube       2009
# 9     Male   28  TAR            Facebook             Youtube       2006
# 10    Male   24  DAM            Telegram             Youtube       2015
# 11    Male   26  HOM            Facebook            Telegram       2011
# ...

# %%
data1.to_csv("D:/Perfect Social Media.csv")
